# %% [markdown]
# <a href="https://colab.research.google.com/github/kurokawa5/practice_leetcode/blob/main/1313_Decompress_Run_Length_Encoded_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def decompressRLElist(self, nums: List[int]) -> List[int]:
        ans = []
        for i in range(1,len(nums),2):
            ans += [nums[i]]*nums[i-1]
        return ans

# %%
nums = [1,2,3,4]
ans = []
for i in range(1,len(nums),2):
    ans += [nums[i]]*nums[i-1]
print(ans)
    #return ans
# Out:
# [2, 4, 4, 4]
