# %% [markdown]
# <a href="https://colab.research.google.com/github/kurokawa5/practice_leetcode/blob/main/1108_Defanging_an_IP_Address.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def defangIPaddr(self, address: str) -> str:
        return address.replace(".","[.]")

# %%
address = "1.1.1.1"

# %%
"[.]".join(address.split("."))
# Out:
# '1[.]1[.]1[.]1'
