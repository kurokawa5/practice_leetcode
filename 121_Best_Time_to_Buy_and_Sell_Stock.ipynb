# %% [markdown]
# <a href="https://colab.research.google.com/github/kurokawa5/practice_leetcode/blob/main/121_Best_Time_to_Buy_and_Sell_Stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        lowest_price = prices[0]
        profit = 0

        for i in range(1,len(prices)):
        	if prices[i] < lowest_price:
        		lowest_price = prices[i]
        	else: # If not then check if it maximizes the profit
        		profit = max(profit, prices[i] - lowest_price)
        return profit #returns the profits
