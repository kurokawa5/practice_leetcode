# %% [markdown]
# <a href="https://colab.research.google.com/github/kurokawa5/practice_leetcode/blob/main/1342_Number_of_Steps_to_Reduce_a_Number_to_Zero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def numberOfSteps(self, num: int) -> int:
        steps = 0
        while num > 0:
            if num % 2 == 0:
                num //= 2 
            else:
                num -=1 
            steps += 1
        return steps
