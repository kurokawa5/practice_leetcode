# %%
class Solution:
    def createTargetArray(self, nums: List[int], index: List[int]) -> List[int]:
        arr = []
        for i, v in zip(index, nums):
            arr.insert(i, v)
        return arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3c5eb03dcfee> in <module>()
# ----> 1 def createTargetArray(self, nums: List[int], index: List[int]) -> List[int]:
#       2     arr = []
#       3     for i, v in zip(index, nums):
#       4         arr.insert(i, v)
#       5         return arr
#
# NameError: name 'List' is not defined
